# %%
import tensorflow as tf 
from tensorflow import keras 
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
(xTrain, yTrain) , (xTest,yTest) = keras.datasets.mnist.load_data()

# %%
len(xTrain)
# Out:
# 60000

# %%
xTrain.shape
# Out:
# (60000, 28, 28)

# %%
plt.matshow(xTrain[5])

# %%
yTrain[5]
# Out:
# 2

# %%
xTrain = xTrain / 255
xTest = xTest / 255

# %%
xTrainF = xTrain.reshape(len(xTrain),28 * 28)
xTestF = xTest.reshape(len(xTest),28 * 28)

# %%
xTestF.shape
# Out:
# (10000, 784)

# %%
model = keras.Sequential([
        keras.layers.Dense(10, input_shape=(784,),activation = 'sigmoid')
])
model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']   
)

model.fit(xTrainF, yTrain, epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 473us/step - accuracy: 0.8176 - loss: 0.7066
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 501us/step - accuracy: 0.9128 - loss: 0.3101
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 485us/step - accuracy: 0.9200 - loss: 0.2842
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 467us/step - accuracy: 0.9248 - loss: 0.2720
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 474us/step - accuracy: 0.9255 - loss: 0.2705
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 493us/step - accuracy: 0.9271 - loss: 0.2592
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 478us/step - accuracy: 0.9283 - loss: 0.2576
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 463us/step - accuracy: 0.9296 - loss: 0.2584
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 479us/step - accuracy: 0.9303 - loss: 0.2543
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 659us/step - accuracy: 0.9312 - loss: 0.2452

# %%
model.evaluate(xTestF,yTest)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step - accuracy: 0.9158 - loss: 0.2973
# [0.2646538019180298, 0.9273999929428101]

# %%
plt.matshow(xTest[100])

# %%
yPredicted = model.predict(xTestF)
yPredicted[100]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step
# array([2.1229843e-03, 3.3571459e-02, 5.3757316e-01, 2.3326879e-02,
#        4.2025452e-03, 6.5702008e-04, 9.7694969e-01, 2.7763465e-04,
#        3.3829983e-03, 4.4874945e-05], dtype=float32)

# %%
np.argmax(yPredicted[100])
# Out:
# 6

# %%
y_predicted_labels = [np.argmax(i) for i in yPredicted ]
y_predicted_labels[:5]
# Out:
# [7, 2, 1, 0, 4]

# %%
cm = tf.math.confusion_matrix(labels = yTest, predictions = y_predicted_labels)
cm
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 962,    0,    2,    2,    0,    4,    7,    2,    1,    0],
#        [   0, 1115,    3,    1,    0,    1,    4,    2,    9,    0],
#        [   6,   10,  931,   14,    8,    3,   13,    8,   36,    3],
#        [   3,    0,   23,  911,    0,   26,    4,   12,   25,    6],
#        [   1,    1,    6,    1,  920,    0,   10,    4,   11,   28],
#        [  10,    3,    1,   25,   10,  781,   17,    7,   33,    5],
#        [  10,    3,    7,    1,    7,   11,  916,    1,    2,    0],
#        [   1,    8,   27,    2,    7,    1,    0,  955,    3,   24],
#        [   7,   12,    6,   17,    8,   19,   11,   12,  877,    5],
#        [  11,    8,    1,    8,   31,    6,    0,   29,    9,  906]])>

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm,annot= True, fmt = 'd')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
model = keras.Sequential([
        keras.layers.Dense(100, input_shape=(784,),activation = 'relu'),
        keras.layers.Dense(10,activation = 'sigmoid')
])
model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']   
)

model.fit(xTrainF, yTrain, epochs = 10)
# Out:
# Epoch 1/10
# C:\Users\NoteBook\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 906us/step - accuracy: 0.8761 - loss: 0.4452
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 897us/step - accuracy: 0.9610 - loss: 0.1347
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 740us/step - accuracy: 0.9736 - loss: 0.0909
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 811us/step - accuracy: 0.9798 - loss: 0.0650
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 768us/step - accuracy: 0.9856 - loss: 0.0479
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 720us/step - accuracy: 0.9887 - loss: 0.0393
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 729us/step - accuracy: 0.9905 - loss: 0.0335
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 826us/step - accuracy: 0.9927 - loss: 0.0262
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 808us/step - accuracy: 0.9932 - loss: 0.0227
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 838us/step - accuracy: 0.9947 - loss: 0.0180

# %%
yPredicted = model.predict(xTestF)
y_predicted_labels = [np.argmax(i) for i in yPredicted ]
cm = tf.math.confusion_matrix(labels = yTest, predictions = y_predicted_labels)
plt.figure(figsize = (10,7))
sn.heatmap(cm,annot= True, fmt = 'd')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step
# Text(95.72222222222221, 0.5, 'Truth')
